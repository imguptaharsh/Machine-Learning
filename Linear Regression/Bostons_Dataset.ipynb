# %%
import pandas as pd
import numpy as np

# %%
data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
x = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
y = raw_df.values[1::2, 2]

# %%
print(x.shape)
print(y.shape)
# Out:
# (506, 13)
# (506,)

# %%
# print(x.feaure_names)
df=pd.DataFrame(x)
print(df.describe())
# Out:
#                0           1           2           3           4           5   \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#                6           7           8           9           10          11  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534    3.613524
# std     28.148861    2.105710    8.707259  168.537116    2.164946    8.601545
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.006320
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000    0.082045
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000    0.256510
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000    3.677083
# max    100.000000   12.126500   24.000000  711.000000   22.000000   88.976200
#
#                12
# count  506.000000
# mean    11.363636
# std     23.322453
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%     12.500000
# max    100.000000

# %%
# Normilise this dataset
# Each feature must have 0 mean, unit variance
u= np.mean(x,axis=0)
std= np.std(x,axis=0)
print(u.shape,std.shape)
# Out:
# (13,) (13,)

# %%
x=(x-u)/std

# %%
print(pd.DataFrame(x[:5,:]).head())
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.419782  0.284830 -1.287909 -0.272599 -0.144217  0.413672 -0.120013
# 1 -0.417339 -0.487722 -0.593381 -0.272599 -0.740262  0.194274  0.367166
# 2 -0.417342 -0.487722 -0.593381 -0.272599 -0.740262  1.282714 -0.265812
# 3 -0.416750 -0.487722 -1.306878 -0.272599 -0.835284  1.016303 -0.809889
# 4 -0.412482 -0.487722 -1.306878 -0.272599 -0.835284  1.228577 -0.511180
#
#          7         8         9         10        11        12
# 0  0.140214 -0.982843 -0.666608 -1.459000 -0.419782  0.284830
# 1  0.557160 -0.867883 -0.987329 -0.303094 -0.417339 -0.487722
# 2  0.557160 -0.867883 -0.987329 -0.303094 -0.417342 -0.487722
# 3  1.077737 -0.752922 -1.106115  0.113032 -0.416750 -0.487722
# 4  1.077737 -0.752922 -1.106115  0.113032 -0.412482 -0.487722

# %%
# Plot y vs any features
import matplotlib.pyplot as plt
plt.scatter(x[:,6],y)
plt.show()
